# %% [markdown]
# # NER Workflow for German Literary Histories

# %% [markdown]
# --- Last edited: 2024-10-01 ---
#
# This workflow is designed to extract named entities of persons and works of art by fine-tuning the existing spaCy NER module. After testing the fine-tuned NER with a manually compiled gold standard, the [spaCy wrapper](https://spacy.io/universe/project/spacyfishing) for  [entity-fishing](https://github.com/kermitt2/entity-fishing) is used to disambiguate the found entities.

# %%
import collections
from datetime import date
import glob
import json
import os
from pathlib import Path
import pickle
import random
import re
import string
import sys
import time
import csv
import shutil
import requests
from tqdm.notebook import tqdm
import ast

import gensim
from gensim.models import Word2Vec
from gensim.test.utils import datapath
from gensim.models import KeyedVectors

import networkx as nx

import nltk
from nltk.corpus import stopwords
from nltk.cluster import KMeansClusterer

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.cm as cm

import sklearn
from sklearn import cluster
from sklearn import metrics
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import adjusted_rand_score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import NMF

import spacy
import spacy_transformers
from spacy.pipeline import EntityRuler
from spacy.training.example import Example
from spacy.scorer import Scorer
from spacy.tokens import DocBin
from spacy.training import offsets_to_biluo_tags

from thefuzz import fuzz
from thefuzz import process

# %% [markdown]
# ### Functions

# %%
def load_data(file):
    with open(file, "r", encoding = "utf-8") as f:
        data = json.load(f)
    return(data)

def save_data(file, data):
    with open(file, "w", encoding = "utf-8") as f:
        json.dump(data, f, indent = 4)

# %%
def test_model(model, text):
    doc = nlp(text)
    results = []
    for ent in doc.ents:
        results.append((ent.text, ent.label_))
    return(results)

# %%
def query_entity_fishing(text, language='de'):
    headers = {
        'Content-Type': 'application/json'
    }
    data = {
        "text": text,
        "language": language  # Specify language if needed
    }
    try:
        # Send a POST request to the Entity Fishing API
        response = requests.post(api_url, headers=headers, data=json.dumps(data))
        # Raise an error for bad HTTP status codes
        response.raise_for_status()
        # Parse the JSON response
        return response.json()
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")  # Handle HTTP errors
        return {}
    except requests.exceptions.RequestException as req_err:
        print(f"Request error: {req_err}")  # Handle other request errors
        return {}
    except ValueError as json_err:
        print(f"JSON decoding error: {json_err}")  # Handle JSON decoding errors
        return {}

# %%
def get_wikidata_label(wikidataid, language='de'):
    # Define the Wikidata API URL
    url = "https://www.wikidata.org/w/api.php"
    
    # Set the parameters for the API request
    params = {
        "action": "wbgetentities",
        "format": "json",
        "ids": wikidataid,
        "props": "labels",
        "languages": language
    }
    
    try:
        # Send the request to the Wikidata API
        response = requests.get(url, params=params)
        response.raise_for_status()
        
        # Parse the JSON response
        data = response.json()
        
        # Extract the label
        entity = data.get("entities", {}).get(wikidataid, {})
        labels = entity.get("labels", {})
        label = labels.get(language, {}).get("value", None)
        
        return label
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")  # Handle HTTP errors
        return None
    except requests.exceptions.RequestException as req_err:
        print(f"Request error: {req_err}")  # Handle other request errors
        return None
    except ValueError as json_err:
        print(f"JSON decoding error: {json_err}")  # Handle JSON decoding errors
        return None

# %%
def is_instance_of_human(wikidata_id):
    # URL to fetch the entity data
    url = f"https://www.wikidata.org/wiki/Special:EntityData/{wikidata_id}.json"
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code != 200:
        return False

    data = response.json()
    
    # Extract the entity data
    entity_data = data['entities'].get(wikidata_id, {})
    
    # Extract claims (properties)
    claims = entity_data.get('claims', {})
    
    # Check for "instance of" property (P31)
    if 'P31' in claims:
        for claim in claims['P31']:
            mainsnak = claim.get('mainsnak', {})
            datavalue = mainsnak.get('datavalue', {})
            value = datavalue.get('value', {})
            if value.get('id') == 'Q5':  # Q5 is the ID for 'human'
                return True
    
    return False

# %%
def is_irrelevant_occupation(wikidata_id):
    import requests

    # URL to fetch the entity data
    url = f"https://www.wikidata.org/wiki/Special:EntityData/{wikidata_id}.json"
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code != 200:
        return False

    data = response.json()
    
    # Extract the entity data
    entity_data = data['entities'].get(wikidata_id, {})
    
    # Extract claims (properties)
    claims = entity_data.get('claims', {})
    
    # List of relevant IDs for athletes, baseball players, American football players, racehorse trainers, basketball players, TV personalities, rappers, jockeys, footballers, golfers, cyclists, handball players, swimmers, and wrestlers
    occupation_ids = [
        'Q937857',    # 'athlete'
        'Q2066131',   # 'sports player'
        'Q10871364',  # 'baseball player'
        'Q19204627',  # 'American football player'
        'Q1622272',   # 'racehorse trainer'
        'Q3665646',   # 'basketball player'
        'Q28389',     # 'TV personality'
        'Q196452',    # 'rapper'
        'Q37226',     # 'jockey'
        'Q2736',      # 'footballer (soccer player)'
        'Q11513337',  # 'golfer'
        'Q14960',     # 'cyclist'
        'Q192061',    # 'handball player'
        'Q24488',     # 'swimmer'
        'Q183'        # 'wrestler'
    ]
    
    # Check for "instance of" property (P31) or "occupation" property (P106)
    for prop in ['P31', 'P106']:
        if prop in claims:
            for claim in claims[prop]:
                mainsnak = claim.get('mainsnak', {})
                datavalue = mainsnak.get('datavalue', {})
                value = datavalue.get('value', {})
                if value.get('id') in occupation_ids:
                    return True

    return False

# %%
def is_instance_of_literarywork(wikidata_id):
    # URL to fetch the entity data
    url = f"https://www.wikidata.org/wiki/Special:EntityData/{wikidata_id}.json"
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code != 200:
        return False

    data = response.json()
    
    # Extract the entity data
    entity_data = data['entities'].get(wikidata_id, {})
    
    # Extract claims (properties)
    claims = entity_data.get('claims', {})
    
    # Check for "instance of" property (P31)
    if 'P31' in claims:
        for claim in claims['P31']:
            mainsnak = claim.get('mainsnak', {})
            datavalue = mainsnak.get('datavalue', {})
            value = datavalue.get('value', {})
            if value.get('id') == 'Q7725634':  # Q7725634 is the ID for 'literary work'
                return True
            if value.get('id') == 'Q47461344':  # Q47461344 is the ID for 'written work'
                return True
            if value.get('id') == 'Q838948':  # Q838948 is the ID for 'work of art'
                return True
            if value.get('id') == 'Q116476516':  # Q116476516 is the ID for 'dramatic work'
                return True
    
    return False

# %% [markdown]
# ### Finetuning spaCy's NER for a Corpus of Literary Historical Texts

# %%
#today = re.sub('-', '', str(date.today()))
today = "20240919"

# %%
base_dir = 'C:/Users/Brottrager/Documents/Diss/sec_lit/GER/'
model_path = 'C:/Users/Brottrager/Documents/Diss/code/python/bespokeNER/output_GER/'
path_results = 'C:/Users/Brottrager/Documents/Diss/sec_lit/GER/' + today + '_wordembeddings'

# %%
if not os.path.exists(path_results):
    os.makedirs(path_results)

# %% [markdown]
# The manually annotated texts are imported, split into sentencens, and then turned into training data in json format.

# %%
corpus_path = base_dir + 'lit_histories_annotated'
corpus_dir = Path(corpus_path).glob('*.txt')
files = list(corpus_dir)

# %%
nlp = spacy.load("de_core_news_lg")

# %%
nlp.max_length = 4000000

# %%
config = {"punct_chars": ['!', '.', '?']}
nlp.add_pipe("sentencizer", config=config, before="parser")

# %%
sentences = []
entities_matches = []
for file in tqdm(files):
    all_paragraphs = ''
    with open (file, encoding = "utf-8") as f:
        text = f.read().split("\n")
        for paragraph in text:
            if paragraph != "":
                doc = nlp(paragraph)
                for sent in doc.sents:
                    newString = str(sent)
                    entities_sent_matches = []
                    num_entities = sum(1 for _ in re.finditer('<.+?>', str(newString)))
                    while num_entities > 0: 
                        entities = re.finditer('<.+?>', str(newString))
                        entities_accum = []
                        for e in entities:
                            #print(e)
                            entity_name = re.sub('<(.+?);.+?>', '\\1', e.group())
                            tag = re.sub('<.+(WORK_OF_ART|PER)>', '\\1', e.group())
                            newString = newString[0:e.start()] + entity_name + newString[e.end():len(newString)]
                            entity_name = re.sub(r'([\(\)\[\]])', r'\\\1', entity_name)
                            entities_accum.append([e.start(), e.start()+len(entity_name), tag])
                            num_entities = num_entities - 1 
                            break
                        entities_sent_matches.append(entities_accum)
                    entities_matches.append([x for xs in entities_sent_matches for x in xs])
                    sentences.append(newString)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
TRAIN_DATA = []
counter = 0
for ent in entities_matches:
    if len(ent) != 0:
        TRAIN_DATA.append([sentences[counter], {"entities":  ent}])
    counter += 1

# %%
save_data(base_dir + today + '_final_manual_training_data_GER.json', TRAIN_DATA)

# %%
GOLD_STANDARD = load_data(base_dir + '20240531_gold_standard_complete.json')

# %%
TRAIN_DATA = load_data(base_dir + today + '_final_manual_training_data_GER.json')

# %% [markdown]
# #### Training

# %%
db = DocBin() # create a DocBin object

for text, annot in tqdm(TRAIN_DATA): # data in previous format
    doc = nlp.make_doc(text) # create doc object from text
    ents = []
    for start, end, label in annot["entities"]: # add character indexes
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents # label the text with the ents
    db.add(doc)

db.to_disk(today + "_final_manual_train_GER.spacy") # save the docbin object
# Out:
#   0%|          | 0/13672 [00:00<?, ?it/s]
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity

# %% [markdown]
# https://spacy.io/usage/training#config
#
# CMD
#
# python -m spacy init fill-config base_config_GER.cfg config.cfg
#
#
# python -m spacy train config.cfg --output ./output_GER --paths.train ./20240821_final_manual_train_GER.spacy --paths.dev ./20240821_final_manual_train_GER.spacy

# %%
trained = spacy.load(r"C:/Users/Brottrager/Documents/Diss/code/python/bespokeNER/output_GER/model-best") 
trained.max_length = 3000000

# %% [markdown]
# #### Testing

# %%
scorer = Scorer()

# %%
examples_nlp = []
for text, annotations in GOLD_STANDARD:
    doc = nlp.make_doc(text)
    example = Example.from_dict(doc, annotations)
    example.predicted = nlp(str(example.predicted))
    examples_nlp.append(example)
# Out:
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Auch hier bleibt seine Gattungslehre abhängig von ..." with entities "[[56, 67, 'PER']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mit Ausnahme der Algabal-Gedichte (1892) des frühe..." with entities "[[17, 24, 'WORK_OF_ART'], [52, 65, 'PER'], [72, 83...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Fragen der weiblichen Sozialisation mit denen der ..." with entities "[[90, 105, 'PER'], [107, 118, 'PER'], [123, 141, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "So sind es vor allem die großen Realisten des 19. ..." with entities "[[82, 89, 'WORK_OF_ART'], [90, 104, 'PER'], [127, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Die hier zutage tretende Ausrichtung an literarisc..." with entities "[[212, 219, 'PER'], [229, 246, 'PER']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Das gilt für die Eklogendichtung ebenso wie für da..." with entities "[[142, 148, 'WORK_OF_ART'], [160, 174, 'PER'], [17...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Enfant perdu: Heinrich Heine
#
# Heinrich Heine (1797..." with entities "[[0, 12, 'WORK_OF_ART'], [14, 28, 'PER'], [30, 44,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Im Gegensatz zu Hölty, der eine Existenz als profe..." with entities "[[16, 21, 'PER'], [102, 107, 'PER'], [113, 117, 'P...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Als wegweisende literarische Vorläufer schätzen di..." with entities "[[52, 67, 'PER'], [82, 104, 'PER'], [118, 137, 'PE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Dass Liebknecht später dennoch "Sänger und Dichter..." with entities "[[5, 10, 'PER'], [77, 89, 'PER'], [91, 100, 'PER']...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Auch die Lektüre von Ovid, aus dessen Ars amatoria..." with entities "[[21, 25, 'PER'], [38, 150, 'WORK_OF_ART'], [214, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Einen wichtigen Hinweis zur Beantwortung dieser Fr..." with entities "[[58, 71, 'PER'], [142, 153, 'PER']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Der Barock-Faust erlebte mehrere Aufl agen und die..." with entities "[[11, 16, 'WORK_OF_ART'], [97, 109, 'PER']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "In der einschlägigen Forschung werden die barocken..." with entities "[[65, 70, 'WORK_OF_ART']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mit Blick auf den Chor der Erinnyen hat bereits Wi..." with entities "[[48, 68, 'PER'], [98, 107, 'PER'], [126, 234, 'PE...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Der Naturalismus in der Rezeption
#
# Thomas Mann (18..." with entities "[[35, 46, 'PER'], [200, 209, 'WORK_OF_ART']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Deshalb kann sich Carriere ohne Weiteres auf Fried..." with entities "[[18, 26, 'PER'], [45, 65, 'PER'], [142, 152, 'PER...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Brottrager\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Dieses hatte bereits Christopher Marlowe zu einer ..." with entities "[[21, 40, 'PER'], [69, 74, 'WORK_OF_ART'], [94, 13...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(

# %%
examples_trained = []
for text, annotations in GOLD_STANDARD:
    doc = nlp.make_doc(text)
    example = Example.from_dict(doc, annotations)
    example.predicted = trained(str(example.predicted))
    examples_trained.append(example)

# %%
dict_scores = [scorer.score(examples_nlp), 
               scorer.score(examples_trained)]

# %%
p_worksofart = []
r_worksofart = []
f_worksofart = []

p_person = []
r_person = []
f_person = []

dicts = ['Base NLP model', 'Fine-tuned model']

i = 0
for d in dict_scores:
    print('========== ' + dicts[i] + ' ==========\n')
    
    print('WORK_OF_ART')
    print('Precision: ' + str(d['ents_per_type']['WORK_OF_ART']['p']))
    print('Recall: ' + str(d['ents_per_type']['WORK_OF_ART']['r']))
    print('F1: ' + str(d['ents_per_type']['WORK_OF_ART']['f']))
    print('\n')
    
    print('PERSON')
    print('Precision: ' + str(d['ents_per_type']['PER']['p']))
    print('Recall: ' + str(d['ents_per_type']['PER']['r']))
    print('F1: ' + str(d['ents_per_type']['PER']['f']))
    print('\n')
    
    i += 1
# Out:
# ========== Base NLP model ==========
#
# WORK_OF_ART
# Precision: 0.0
# Recall: 0.0
# F1: 0.0
#
#
# PERSON
# Precision: 0.7861080485115767
# Recall: 0.9235751295336787
# F1: 0.8493150684931506
#
#
# ========== Fine-tuned model ==========
#
# WORK_OF_ART
# Precision: 0.7034883720930233
# Recall: 0.7492260061919505
# F1: 0.7256371814092952
#
#
# PERSON
# Precision: 0.8846625766871166
# Recall: 0.9339378238341969
# F1: 0.9086326402016384

# %% [markdown]
# ### Entity fishing

# %% [markdown]
# docker run --rm -p 8090:8090 -p 8091:8091 \
#
# -v C:/entity-fishing/data/db-kb/db-kb:/opt/entity-fishing/data/db/db-kb \
#
# -v C:/entity-fishing/data/db-en/db-en:/opt/entity-fishing/data/db/db-en \
#
# -v C:/entity-fishing/data/db-de/db-de:/opt/entity-fishing/data/db/db-de \
#
# grobid/entity-fishing:0.0.6

# %%
trained.add_pipe("entityfishing", config={"extra_info": True, "filter_statements":['P569', 'P570'], "language": "de", "api_ef_base": "http://localhost:8090/service"})

# %%
corpus_path = base_dir + 'lit_histories_preprocessed'
corpus_dir = Path(corpus_path).glob('*.txt')
files = list(corpus_dir)

# %%
newpath = base_dir + today + '_txt_search&replace_model=trained'
if not os.path.exists(newpath):
    os.makedirs(newpath)

# %% [markdown]
# #### Search & Replace Logic

# %%
persons = []
works_of_art = []
for file in tqdm(files):
    all_paragraphs = ''
    with open (file, encoding = 'utf-8') as f:
        text = f.read().split('\n')
        for paragraph in text:
            doc = trained(paragraph)
            newString = paragraph
            for e in reversed(doc.ents): #reversed to not modify the offsets of other entities when substituting
                if e.label_ == 'PER':
                    label = 'PERSON'
                    start = e.start_char
                    end = start + len(e.text)
                    if str(e._.normal_term).upper() != 'NONE':
                        normalised = str(e._.normal_term).upper().replace(' ', '_')
                        normalised = normalised.replace(',', '')
                        newString = newString[:start] + '<' + e.text + '; ' + normalised + '; ' + str(e._.kb_qid) + '; ' + label + '>' +  newString[end:]
                        works_of_art.append([e.text + "," + str(e._.normal_term).upper().replace(' ', '_')  + "," + str(e._.kb_qid) + "," + label])
                    else:
                        newString = newString[:start] + '<' + e.text + '; ' + e.text.upper().replace(' ', '_') + '; noWikiID; ' + label +'>' + newString[end:]
                        works_of_art.append([e.text + "," + e.text.upper().replace(' ', '_')  + "," + str(e._.kb_qid) + "," + label])
                if e.label_ == 'WORK_OF_ART':
                    start = e.start_char
                    end = start + len(e.text)
                    if str(e._.normal_term).upper() != 'NONE':
                        normalised = str(e._.normal_term).upper().replace(' ', '_')
                        normalised = normalised.replace(',', '')
                        newString = newString[:start] + '<' + e.text + '; ' + normalised + '; ' + str(e._.kb_qid) + '; ' + e.label_ + '>' +  newString[end:]
                        works_of_art.append([e.text + "," + str(e._.normal_term).upper().replace(' ', '_')  + "," + str(e._.kb_qid) + "," + e.label_])
                    else:
                        newString = newString[:start] + '<' + e.text + '; ' + e.text.upper().replace(' ', '_') + '; noWikiID; ' + e.label_ +'>' + newString[end:]
                        works_of_art.append([e.text + "," + e.text.upper().replace(' ', '_')  + "," + str(e._.kb_qid) + "," + e.label_])

            all_paragraphs = all_paragraphs + '\n' + newString
                
        file_name = re.sub('.+lit_histories_preprocessed.(.+.txt)', '\\1', str(file))
        file_name = newpath + '/' + file_name
        f = open(file_name, 'w',  encoding = 'utf-8')
        f.write(all_paragraphs)
        f.close()

# %%
newpath = base_dir + today + '_final_corpus_GER'
if not os.path.exists(newpath):
    os.makedirs(newpath)

# %%
corpus_path = base_dir + today + '_txt_search&replace_model=trained'
corpus_dir = Path(corpus_path).glob('*.txt')
files = list(corpus_dir)

# %% [markdown]
# The newly annotated files are now copied into a new directory, together with the manually annotated files. Here, I also went through a first round of manual correction, replacing obvious mis-identifications.

# %%
for file in files:
    file_name = re.sub('.+txt_search&replace_model=trained.(.+.txt)', '\\1', str(file))
    new_file_name = newpath + '/' + file_name
    shutil.copyfile(file, new_file_name)

# %%
annotated = base_dir + 'lit_histories_annotated'
corpus_dir = Path(annotated).glob('*.txt')
files = list(corpus_dir)

# %%
for file in files:
    file_name = re.sub('.+lit_histories_annotated.(.+.txt)', '\\1', str(file))
    new_file_name = newpath + '/' + file_name
    shutil.copyfile(file, new_file_name)

# %%
corpus_path = base_dir + today + '_final_corpus_GER'
corpus_dir = Path(corpus_path).glob('*.txt')
files = list(corpus_dir)

# %% [markdown]
# Replace all "PER" by "PERSON"

# %% [markdown]
# To prepare a consolidation of name variations, all detected entities that have a wikiID are extracted from the text files---both automatically and manually annotated---and are stored in two dictionaries.

# %%
dict_per = {}
dict_text = {}

for file in tqdm(files):
    with open (file, encoding = "utf-8") as f:
        text = f.read()
        matches = re.findall( r'<.+?>', text)
        for m in matches:
            if len(re.findall(';', m)) > 1:
                key = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\1', m)
                wikiname = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\2', m)
                wikiID = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\3', m)
                tag = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\4', m)
                if tag == 'PERSON':
                    if wikiID != 'noWikiID':
                        if wikiname in dict_per:
                            if key in dict_per[wikiname][0]:
                                dict_per[wikiname][3] += 1
                            else:
                                dict_per[wikiname][0].append(key)
                                dict_per[wikiname][3] += 1
                        else:
                            dict_per[wikiname] = [[key], wikiID, tag, 1]
                elif tag == 'WORK_OF_ART':
                    if wikiID != 'noWikiID':
                        if wikiname in dict_text:
                            if key in dict_text[wikiname][0]:
                                dict_text[wikiname][3] += 1
                            else:
                                dict_text[wikiname][0].append(key)
                                dict_text[wikiname][3] += 1
                        else:
                            dict_text[wikiname] = [[key], wikiID, tag, 1]
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]

# %%
keys = list(dict_per.keys())
keys.sort()
dict_per = {i: dict_per[i] for i in keys}

# %%
keys = list(dict_text.keys())
keys.sort()
dict_text = {i: dict_text[i] for i in keys}

# %% [markdown]
# These dictionaries are now filtered: dict_per_filtered should only include entries that are linked to a person, dict_text_filtered only entries that are a written work, literary work, and so on. This helps to exclude non-sensical but common mis-identifications (city names, race horses, athletes, you name it).

# %%
dict_per_filtered = {}

for key, values in tqdm(dict_per.items()):
    if is_instance_of_human(values[1]) == True:
        if is_irrelevant_occupation(values[1]) == False:
            dict_per_filtered[key] = values
# Out:
#   0%|          | 0/9039 [00:00<?, ?it/s]

# %%
dict_text_filtered = {}

for key, values in tqdm(dict_text.items()):
    if is_instance_of_literarywork(values[1]) == True:
        dict_text_filtered[key] = values
# Out:
#   0%|          | 0/6662 [00:00<?, ?it/s]

# %%
save_data(base_dir + today + '_GER_dict_entities_PER.json', dict_per_filtered)
save_data(base_dir + today + '_GER_dict_entities_WORK_OF_ART.json', dict_text_filtered)

# %%
#dict_per_filtered = load_data(base_dir + today + '_GER_dict_entities_PER.json')
#dict_text_filtered = load_data(base_dir + today + '_GER_dict_entities_WORK_OF_ART.json')

# %% [markdown]
# The dictionaries are now inverted; with the different name variations as keys and the wikinames as values.

# %%
inverted_dict_per = {}

for key, values in dict_per_filtered.items():
    for value in values[0]:
        if value in inverted_dict_per:
            inverted_dict_per.pop(value)
        else:
            inverted_dict_per[value] = key

# %%
inverted_dict_text = {}

for key, values in dict_text_filtered.items():
    for value in values[0]:
        if value in inverted_dict_text:
            inverted_dict_text.pop(value)
        else:
            inverted_dict_text[value] = key

# %%
consolidated_dir = base_dir + today + '_final_corpus_GER_consolidated'
if not os.path.exists(consolidated_dir):
    os.makedirs(consolidated_dir)

# %% [markdown]
# In the second iteration, all entities that have not been attributed a wikiID are compared to existing entries in both dictioniaries and are, if applicable, updated to match the dictionary information. If an entity has been deleted from a dictionary (because, for example, is_instance_of_human yielded False), the entity is also compared to existing disambiguated entities or updated to a 'noWikiID' entry.

# %%
for file in tqdm(files):
    with open (file, encoding = "utf-8") as f:
        text = f.read().split("\n")
        newText = ''
        for paragraph in text:
            newString = paragraph
            entities = re.finditer('<.+?>', newString)
            if entities is not None:
                for e in reversed(list(entities)):
                    key = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\1', e.group())
                    wikiname = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\2', e.group())
                    wikiID = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\3', e.group())
                    tag = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\4', e.group())
                    if tag == 'PERSON':
                        if wikiID == 'noWikiID':
                            if wikiname in dict_per_filtered:
                                wikiID = dict_per_filtered[wikiname][2]
                            elif key in inverted_dict_per:
                                wikiname = inverted_dict_per[key]
                                wikiID = dict_per_filtered[inverted_dict_per[key]][1]
                            else:
                                fuzzy_matches = process.extract(key, inverted_dict_per.keys())
                                if fuzzy_matches[0][1] >= 95:
                                    wikiname = inverted_dict_per[fuzzy_matches[0][0]]
                                    wikiID = dict_per_filtered[inverted_dict_per[fuzzy_matches[0][0]]][1]
                                    
                            newString = newString[0:e.start()] + '<' + key + '; ' + wikiname + '; ' + wikiID + '; ' + tag + '>' + newString[e.end():len(newString)]

                        else:
                            if wikiname not in dict_per_filtered:
                                if key in inverted_dict_per:
                                    wikiname = inverted_dict_per[key]
                                    wikiID = dict_per_filtered[inverted_dict_per[key]][1]
                                else:
                                    wikiname = key.upper().replace(' ', '_')
                                    wikiname = wikiname.replace(',', '')
                                    wikiID = 'noWikiID'
                                    
                            newString = newString[0:e.start()] + '<' + key + '; ' + wikiname + '; ' + wikiID + '; ' + tag + '>' + newString[e.end():len(newString)]
                    if tag == 'WORK_OF_ART':
                        if wikiID == 'noWikiID':
                            if wikiname in dict_text_filtered:
                                wikiID = dict_text_filtered[wikiname][2]
                            elif key in inverted_dict_text:
                                wikiname = inverted_dict_text[key]
                                wikiID = dict_text_filtered[inverted_dict_text[key]][1]
                            else:
                                fuzzy_matches = process.extract(key, inverted_dict_text.keys())
                                if fuzzy_matches[0][1] >= 95:
                                    wikiname = inverted_dict_text[fuzzy_matches[0][0]]
                                    wikiID = dict_text_filtered[inverted_dict_text[fuzzy_matches[0][0]]][1]
                                    
                            newString = newString[0:e.start()] + '<' + key + '; ' + wikiname + '; ' + wikiID + '; ' + tag + '>' + newString[e.end():len(newString)]
                        
                        else:
                            if wikiname not in dict_text_filtered:
                                if key in inverted_dict_text:
                                    wikiname = inverted_dict_text[key]
                                    wikiID = dict_text_filtered[inverted_dict_text[key]][1]
                                else:
                                    wikiname = key.upper().replace(' ', '_')
                                    wikiname = wikiname.replace(',', '')
                                    wikiID = 'noWikiID'
                                    
                                newString = newString[0:e.start()] + '<' + key + '; ' + wikiname + '; ' + wikiID + '; ' + tag + '>' + newString[e.end():len(newString)]
            
            newText = newText + '\n' + newString
            
    file_name = re.sub('.+GER.(.+.txt)', '\\1', str(file))
    file_name = consolidated_dir + '/' + file_name
    f = open(file_name, "w",  encoding = "utf-8")
    f.write(newText)
    f.close()
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]

# %%
corpus_path = base_dir + today + '_final_corpus_GER_consolidated'
corpus_dir = Path(corpus_path).glob('*.txt')
files = list(corpus_dir)

# %% [markdown]
# Based on the consolidated text files two new dictionaries are compiled that now include all detected entities, with or without wikiIDs, for persons and literary texts, respectively. They are sorted alphabetically, and then exported as json and csv files.

# %%
dict_per = {}
dict_text = {}

for file in tqdm(files):
    with open (file, encoding = "utf-8") as f:
        text = f.read()
        matches = re.findall( r'<.+?>', text)
        for m in matches:
            if len(re.findall(';', m)) > 1:
                key = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\1', m)
                wikiname = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\2', m)
                wikiID = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\3', m)
                tag = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\4', m)
                if tag == 'PERSON':
                    if wikiname in dict_per:
                        if key in dict_per[wikiname][0]:
                            dict_per[wikiname][3] += 1
                        else:
                            dict_per[wikiname][0].append(key)
                            dict_per[wikiname][3] += 1
                    else:
                        dict_per[wikiname] = [[key], wikiID, tag, 1]
                elif tag == 'WORK_OF_ART':
                    if wikiname in dict_text:
                        if key in dict_text[wikiname][0]:
                            dict_text[wikiname][3] += 1
                        else:
                            dict_text[wikiname][0].append(key)
                            dict_text[wikiname][3] += 1
                    else:
                        dict_text[wikiname] = [[key], wikiID, tag, 1]
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]

# %%
keys = list(dict_per.keys())
keys.sort()
dict_per = {i: dict_per[i] for i in keys}

# %%
keys = list(dict_text.keys())
keys.sort()
dict_text = {i: dict_text[i] for i in keys}

# %%
save_data(base_dir + today + '_GER_dict_all_entities_PER.json', dict_per)
save_data(base_dir + today + '_GER_dict_all_entities_WORK_OF_ART.json', dict_text)

# %%
#dict_per = load_data(base_dir + today + '_GER_dict_all_entities_PER.json')
#dict_text = load_data(base_dir + today + '_GER_dict_all_entities_WORK_OF_ART.json')

# %%
titles = list(dict_text.keys())
details = list(dict_text.values())

# Convert to DataFrame
df = pd.DataFrame(details, columns=['variations', 'wikiID', 'tag', 'count'])
df.insert(0, 'wikiname', titles)

# %%
df.to_csv(base_dir + today + '_texts_df_tobeclustered.csv', encoding='utf8')

# %%
persons = list(dict_per.keys())
details = list(dict_per.values())

# Convert to DataFrame
df = pd.DataFrame(details, columns=['variations', 'wikiID', 'tag', 'count'])
df.insert(0, 'wikiname', persons)

# %%
df.to_csv(base_dir + today + '_persons_df_tobeclustered.csv', encoding='utf8')

# %% [markdown]
# ### OpenRefine

# %% [markdown]
# OpenRefine: export as xslx, save as csv

# %%
df_texts = pd.read_csv(base_dir + today + '-texts-df-clustered.csv', encoding='utf8', sep=';')
df_persons = pd.read_csv(base_dir + today + '-persons-df-clustered.csv', encoding='utf8', sep=';')

# %%
df_texts['variations'] = df_texts['variations'].apply(ast.literal_eval)
df_persons['variations'] = df_persons['variations'].apply(ast.literal_eval)

# %%
dict_text_clustered = {}

for index, row in df_texts.iterrows():
    if row.iloc[1] in dict_text_clustered: # is wikiname in dict?
        dict_text_clustered[row.iloc[1]][0] = dict_text_clustered[row.iloc[1]][0] + row.iloc[2] # if yes, then add variations and check if wikiID can be added
        if row.iloc[3] != "noWikiID": 
            dict_text_clustered[row.iloc[1]][1] = row.iloc[3]
        dict_text_clustered[row.iloc[1]][3] += row.iloc[5] # add up the count
    else:
        dict_text_clustered[row.iloc[1]] = [row.iloc[2], row.iloc[3], row.iloc[4], row.iloc[5]] # wikiname, variations, wikiID; tag, count

# %%
dict_persons_clustered = {}

for index, row in df_persons.iterrows():
    if row.iloc[1] in dict_persons_clustered: # is wikiname in dict?
        dict_persons_clustered[row.iloc[1]][0] = dict_persons_clustered[row.iloc[1]][0] + row.iloc[2] # if yes, then add variations and check if wikiID can be added
        if row.iloc[3] != "noWikiID": 
            dict_persons_clustered[row.iloc[1]][1] = row.iloc[3]
        dict_persons_clustered[row.iloc[1]][3] += row.iloc[5] # add up the count
    else:
        dict_persons_clustered[row.iloc[1]] = [row.iloc[2], row.iloc[3], row.iloc[4], row.iloc[5]] # wikiname, variations, wikiID; tag, count

# %%
#save_data(base_dir + today + '_GER_dict_all_entities_WORK_OF_ART_final.json', dict_text_clustered)
#save_data(base_dir + today + '_GER_dict_all_entities_PERSON_final.json', dict_persons_clustered)

# %%
dict_text_clustered = load_data(base_dir + today + '_GER_dict_all_entities_WORK_OF_ART_final.json')
dict_persons_clustered = load_data(base_dir + today + '_GER_dict_all_entities_PERSON_final.json')

# %%
dict_text_clustered_inverted = {}

for key, values in dict_text_clustered.items():
    for value in values[0]:
        dict_text_clustered_inverted[value] = key

# %%
dict_persons_clustered_inverted = {}

for key, values in dict_persons_clustered.items():
    for value in values[0]:
        dict_persons_clustered_inverted[value] = key

# %%
clustered_dir = base_dir + today + '_final_corpus_GER_clustered'
if not os.path.exists(clustered_dir):
    os.makedirs(clustered_dir)

# %%
co_citation_dict = {}

for file in tqdm(files):
    file_short = re.sub('(.+consolidated)\\\\(.+?).txt', '\\2', str(file))
    co_citation_dict[file_short] = {'texts': {}, 'persons': {}}
    with open (file, encoding = "utf-8") as f:
        text = f.read().split("\n")
        newText = ''
        for paragraph in text:
            newString = paragraph
            entities = re.finditer('<.+?>', newString)
            if entities is not None:
                for e in reversed(list(entities)):
                    key = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\1', e.group())
                    wikiname = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\2', e.group())
                    wikiID = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\3', e.group())
                    tag = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\4', e.group())

                    if tag == 'PERSON':
                        if wikiname not in co_citation_dict[file_short]['persons']:
                            co_citation_dict[file_short]['persons'][wikiname] = 1
                        else:
                            co_citation_dict[file_short]['persons'][wikiname] += 1
                    if tag == 'WORK_OF_ART':
                        if wikiname not in co_citation_dict[file_short]['texts']:
                            co_citation_dict[file_short]['texts'][wikiname] = 1
                        else:
                            co_citation_dict[file_short]['texts'][wikiname] += 1
                    
                    if tag == 'PERSON':
                        if wikiname in dict_persons_clustered:
                            newString = newString[0:e.start()] + '<' + key + '; ' + str(wikiname) + '; ' + wikiID + '; ' + tag + '>' + newString[e.end():len(newString)]
                        else:
                            if key in dict_persons_clustered_inverted: # if an entity doesn't appear in the dictionary, the title variation is looked up in the inverted dictionary and the entity name is, if applicable, replaced
                                wikiname = dict_persons_clustered_inverted[key]
                                wikiID = dict_persons_clustered[dict_persons_clustered_inverted[key]][1]
                                newString = newString[0:e.start()] + '<' + key + '; ' + str(wikiname) + '; ' + wikiID + '; ' + tag + '>' + newString[e.end():len(newString)]
                            else:
                                newString = newString[0:e.start()] + key + newString[e.end():len(newString)]
                                
                    if tag == 'WORK_OF_ART':
                        if wikiname in dict_text_clustered:
                            newString = newString[0:e.start()] + '<' + key + '; ' + str(wikiname) + '; ' + wikiID + '; ' + tag + '>' + newString[e.end():len(newString)]
                        else:
                            if key in dict_text_clustered_inverted: # if an entity doesn't appear in the dictionary, the title variation is looked up in the inverted dictionary and the entity name is, if applicable, replaced
                                wikiname = dict_text_clustered_inverted[key]
                                wikiID = dict_text_clustered[dict_text_clustered_inverted[key]][1]
                                newString = newString[0:e.start()] + '<' + key + '; ' + str(wikiname) + '; ' + wikiID + '; ' + tag + '>' + newString[e.end():len(newString)]
                            else:
                                newString = newString[0:e.start()] + key + newString[e.end():len(newString)]

            newText = newText + '\n' + newString
            
    file_name = re.sub('.+consolidated.(.+.txt)', '\\1', str(file))
    file_name = clustered_dir + '/' + file_name
    f = open(file_name, "w",  encoding = "utf-8")
    f.write(newText)
    f.close()
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]

# %%
save_data(base_dir + today + '_co_citation_dict.json', co_citation_dict)

# %%
corpus_path = base_dir + today + '_final_corpus_GER_clustered'
corpus_dir = Path(corpus_path).glob('*.txt')
files = list(corpus_dir)

# %%
replaced_dir = base_dir + today + '_final_corpus_GER_replaced'
if not os.path.exists(replaced_dir):
    os.makedirs(replaced_dir)

# %%
for file in tqdm(files):
    with open (file, encoding = "utf-8") as f:
        text = f.read().split("\n")
        newText = ''
        for paragraph in text:
            newString = paragraph
            entities = re.finditer('<.+?>', newString)
            if entities is not None:
                for e in reversed(list(entities)):
                    key = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\1', e.group())
                    wikiname = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\2', e.group())
                    wikiID = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\3', e.group())
                    tag = re.sub('<(.+?); ([A-Z].+?); (Q.+?|noWikiID); (PERSON|WORK_OF_ART)>', '\\4', e.group())
                    
                    newString = newString[0:e.start()] + wikiname + '_' + wikiID + newString[e.end():len(newString)]

            newText = newText + '\n' + newString

    file_name = re.sub('.+GER_clustered.(.+.txt)', '\\1', str(file))
    file_name = replaced_dir + '/' + file_name
    f = open(file_name, "w",  encoding = "utf-8")
    f.write(newText)
    f.close()
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]

# %% [markdown]
# ### Word Embedding

# %%
entities_per = []

for key, values in dict_persons_clustered.items():
    entity = str(key) + '_' + values[1]
    entities_per.append(entity)

entities_text = []

for key, values in dict_text_clustered.items():
    entity = str(key) + '_' + values[1]
    entities_text.append(entity)

# %%
len(entities_per)
# Out:
# 15491

# %%
len(entities_text)
# Out:
# 33779

# %%
entities = set(entities_per + entities_text)

# %%
fileList = glob.glob(os.path.join(os.getcwd(), replaced_dir, '*.txt'))
 
lithist = []
for file_path in fileList:
    with open(file_path, encoding = 'utf8') as file:
        lithist.append(file.read())

# %%
escape = "!#$%&'()*+–, -./:;<=>?@[\]^`{|}~’‘“”"

# %%
tokens = []

num_tokens = 0
for hist in tqdm(lithist):
    doc = nlp(hist)
    for sent in doc.sents:
        tokens_in_sent = []
        for token in sent:
            
            if token.text.startswith('\n'):
                continue
            if token.text[0].isdigit():
                continue
            if token.text in escape:
                continue
              
            if token.text not in entities:
                tok = re.sub('[\d!#$%&\(\)*\+, -\./:;<=>?@\[\]^`\{\|\}~’‘“”]+', '', token.text)
                tokens_in_sent.append(tok.lower())
            else:
                tokens_in_sent.append(token.text)

        tokens.append(tokens_in_sent)
        num_tokens += len(tokens_in_sent)
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]

# %%
num_tokens
# Out:
# 3652548

# %%
#with open(path_results + '\\' + today + '_tokens_preprocessed.pickle', 'wb') as output_file:
#    pickle.dump(tokens, output_file)

# %%
with open(path_results + '\\' + today + '_tokens_preprocessed.pickle',  'rb') as input_file:
    tokens = pickle.load(input_file)

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', 
                    level=logging.INFO)

# %%
min_count = 5
vector_size = 100
window = 10
sg = 1
epochs = 5

# %%
iterations = 100

# %%
model = Word2Vec(tokens, min_count=min_count, vector_size=vector_size, window=window, sg=sg, epochs=epochs)
# Out:
# 2024-10-18 13:28:21,167 : INFO : collecting all words and their counts
# 2024-10-18 13:28:21,168 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-10-18 13:28:21,247 : INFO : PROGRESS: at sentence #10000, processed 277781 words, keeping 38708 word types
# 2024-10-18 13:28:21,322 : INFO : PROGRESS: at sentence #20000, processed 573185 words, keeping 63626 word types
# 2024-10-18 13:28:21,396 : INFO : PROGRESS: at sentence #30000, processed 856107 words, keeping 86692 word types
# 2024-10-18 13:28:21,481 : INFO : PROGRESS: at sentence #40000, processed 1117523 words, keeping 104095 word types
# 2024-10-18 13:28:21,574 : INFO : PROGRESS: at sentence #50000, processed 1404857 words, keeping 119278 word types
# 2024-10-18 13:28:21,642 : INFO : PROGRESS: at sentence #60000, processed 1682965 words, keeping 133037 word types
# 2024-10-18 13:28:21,706 : INFO : PROGRESS: at sentence #70000, processed 1911646 words, keeping 148099 word types
# 2024-10-18 13:28:21,773 : INFO : PROGRESS: at sentence #80000, processed 2175572 words, keeping 161655 word types
# 2024-10-18 13:28:21,845 : INFO : PROGRESS: at sentence #90000, processed 2407307 words, keeping 174826 word types
# 2024-10-18 13:28:21,915 : INFO : PROGRESS: at sentence #100000, processed 2660004 words, keeping 190384 word types
# 2024-10-18 13:28:21,983 : INFO : PROGRESS: at sentence #110000, processed 2939003 words, keeping 200941 word types
# 2024-10-18 13:28:22,055 : INFO : PROGRESS: at sentence #120000, processed 3248529 words, keeping 208657 word types
# 2024-10-18 13:28:22,127 : INFO : PROGRESS: at sentence #130000, processed 3528600 words, keeping 222921 word types
# 2024-10-18 13:28:22,169 : INFO : collected 231874 word types from a corpus of 3652548 raw words and 135024 sentences
# 2024-10-18 13:28:22,170 : INFO : Creating a fresh vocabulary
# 2024-10-18 13:28:22,383 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 41406 unique words (17.86% of original 231874, drops 190468)', 'datetime': '2024-10-18T13:28:22.383504', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2024-10-18 13:28:22,384 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 3374733 word corpus (92.39% of original 3652548, drops 277815)', 'datetime': '2024-10-18T13:28:22.384672', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2024-10-18 13:28:22,636 : INFO : deleting the raw counts dictionary of 231874 items
# 2024-10-18 13:28:22,642 : INFO : sample=0.001 downsamples 41 most-common words
# 2024-10-18 13:28:22,643 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2598336.545976942 word corpus (77.0%% of prior 3374733)', 'datetime': '2024-10-18T13:28:22.643890', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2024-10-18 13:28:23,034 : INFO : estimated required memory for 41406 words and 100 dimensions: 53827800 bytes
# 2024-10-18 13:28:23,035 : INFO : resetting layer weights
# 2024-10-18 13:28:23,058 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-10-18T13:28:23.058318', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'build_vocab'}
# 2024-10-18 13:28:23,060 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 41406 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2024-10-18T13:28:23.059319', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2024-10-18 13:28:24,068 : INFO : EPOCH 0 - PROGRESS: at 7.18% examples, 194808 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28:25,069 : INFO : EPOCH 0 - PROGRESS: at 15.16% examples, 212112 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28:26,073 : INFO : EPOCH 0 - PROGRESS: at 23.80% examples, 216149 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28:27,120 : INFO : EPOCH 0 - PROGRESS: at 32.58% examples, 217711 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28:28,121 : INFO : EPOCH 0 - PROGRESS: at 40.93% examples, 219058 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28:29,156 : INFO : EPOCH 0 - PROGRESS: at 50.41% examples, 218567 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28:30,175 : INFO : EPOCH 0 - PROGRESS: at 59.47% examples, 219296 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28:31,190 : INFO : EPOCH 0 - PROGRESS: at 69.47% examples, 219669 words/s, in_qsize 6, out_qsize 0
# 2024-10-18 13:28:32,228 : INFO : EPOCH 0 - PROGRESS: at 78.71% examples, 219450 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28:33,234 : INFO : EPOCH 0 - PROGRESS: at 85.42% examples, 217092 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28:34,258 : INFO : EPOCH 0 - PROGRESS: at 91.66% examples, 215014 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28:35,172 : INFO : EPOCH 0: training on 3652548 raw words (2598987 effective words) took 12.1s, 214688 effective words/s
# 2024-10-18 13:28:36,182 : INFO : EPOCH 1 - PROGRESS: at 6.90% examples, 187659 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28:37,191 : INFO : EPOCH 1 - PROGRESS: at 13.54% examples, 186356 words/s, in_qsize 6, out_qsize 0
# 2024-10-18 13:28:38,208 : INFO : EPOCH 1 - PROGRESS: at 20.98% examples, 191074 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:28
words/s, in_qsize 6, out_qsize 0
# 2024-10-18 13:29:15,614 : INFO : EPOCH 3: training on 3652548 raw words (2597963 effective words) took 14.1s, 184055 effective words/s
# 2024-10-18 13:29:16,631 : INFO : EPOCH 4 - PROGRESS: at 6.34% examples, 172044 words/s, in_qsize 6, out_qsize 0
# 2024-10-18 13:29:17,686 : INFO : EPOCH 4 - PROGRESS: at 13.26% examples, 178221 words/s, in_qsize 6, out_qsize 0
# 2024-10-18 13:29:18,689 : INFO : EPOCH 4 - PROGRESS: at 20.20% examples, 181823 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:29:19,690 : INFO : EPOCH 4 - PROGRESS: at 28.63% examples, 188920 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:29:20,695 : INFO : EPOCH 4 - PROGRESS: at 35.15% examples, 188334 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:29:21,718 : INFO : EPOCH 4 - PROGRESS: at 42.49% examples, 189467 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:29:22,746 : INFO : EPOCH 4 - PROGRESS: at 51.05% examples, 188786 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:29:23,758 : INFO : EPOCH 4 - PROGRESS: at 58.79% examples, 188889 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:29:24,796 : INFO : EPOCH 4 - PROGRESS: at 68.09% examples, 190599 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:29:25,815 : INFO : EPOCH 4 - PROGRESS: at 77.25% examples, 192960 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:29:26,882 : INFO : EPOCH 4 - PROGRESS: at 84.21% examples, 192662 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:29:27,906 : INFO : EPOCH 4 - PROGRESS: at 90.30% examples, 192417 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:29:28,911 : INFO : EPOCH 4 - PROGRESS: at 98.21% examples, 192419 words/s, in_qsize 5, out_qsize 0
# 2024-10-18 13:29:29,121 : INFO : EPOCH 4: training on 3652548 raw words (2597775 effective words) took 13.5s, 192452 effective words/s
# 2024-10-18 13:29:29,122 : INFO : Word2Vec lifecycle event {'msg': 'training on 18262740 raw words (12991183 effective words) took 66.1s, 196652 effective words/s', 'datetime': '2024-10-18T13:29:29.122340', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2024-10-18 13:29:29,123 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=41406, vector_size=100, alpha=0.025>', 'datetime': '2024-10-18T13:29:29.123351', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'created'}

# %%
we_results = path_results + '\\modelA_iteration=' + str(iterations)
if not os.path.exists(we_results):
    os.makedirs(we_results)

# %%
models = []
for i in range(1, iterations+1):
    model = Word2Vec(tokens, min_count=min_count, vector_size=vector_size, window=window, sg=sg, epochs=epochs)
    model.wv.save(path_results + '\\modelA_iteration=' + str(iterations) + '\\' + today + '_' + str(i) + '_window=' + str(window) + '_skipgram_defaultparams_model_vectors.kv')
    models.append(model)
# Out:
# 2024-10-02 17:40:14,024 : INFO : collecting all words and their counts
# 2024-10-02 17:40:14,026 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-10-02 17:40:14,144 : INFO : PROGRESS: at sentence #10000, processed 277781 words, keeping 38708 word types
# 2024-10-02 17:40:14,269 : INFO : PROGRESS: at sentence #20000, processed 573185 words, keeping 63626 word types
# 2024-10-02 17:40:14,393 : INFO : PROGRESS: at sentence #30000, processed 856107 words, keeping 86692 word types
# 2024-10-02 17:40:14,508 : INFO : PROGRESS: at sentence #40000, processed 1117523 words, keeping 104095 word types
# 2024-10-02 17:40:14,636 : INFO : PROGRESS: at sentence #50000, processed 1404857 words, keeping 119278 word types
# 2024-10-02 17:40:14,750 : INFO : PROGRESS: at sentence #60000, processed 1682965 words, keeping 133037 word types
# 2024-10-02 17:40:14,860 : INFO : PROGRESS: at sentence #70000, processed 1911646 words, keeping 148099 word types
# 2024-10-02 17:40:14,986 : INFO : PROGRESS: at sentence #80000, processed 2175572 words, keeping 161655 word types
# 2024-10-02 17:40:15,108 : INFO : PROGRESS: at sentence #90000, processed 2407307 words, keeping 174826 word types
# 2024-10-02 17:40:15,220 : INFO : PROGRESS: at sentence #100000, processed 2660004 words, keeping 190384 word types
# 2024-10-02 17:40:15,348 : INFO : PROGRESS: at sentence #110000, processed 2939003 words, keeping 200941 word types
# 2024-10-02 17:40:15,463 : INFO : PROGRESS: at sentence #120000, processed 3248529 words, keeping 208657 word types
# 2024-10-02 17:40:15,578 : INFO : PROGRESS: at sentence #130000, processed 3528600 words, keeping 222921 word types
# 2024-10-02 17:40:15,639 : INFO : collected 231874 word types from a corpus of 3652548 raw words and 135024 sentences
# 2024-10-02 17:40:15,640 : INFO : Creating a fresh vocabulary
# 2024-10-02 17:40:15,965 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 41406 unique words (17.86% of original 231874, drops 190468)', 'datetime': '2024-10-02T17:40:15.965548', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2024-10-02 17:40:15,967 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 3374733 word corpus (92.39% of original 3652548, drops 277815)', 'datetime': '2024-10-02T17:40:15.967546', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2024-10-02 17:40:16,386 : INFO : deleting the raw counts dictionary of 231874 items
# 2024-10-02 17:40:16,394 : INFO : sample=0.001 downsamples 41 most-common words
# 2024-10-02 17:40:16,396 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2598336.545976942 word corpus (77.0%% of prior 3374733)', 'datetime': '2024-10-02T17:40:16.396106', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2024-10-02 17:40:17,023 : INFO : estimated required memory for 41406 words and 100 dimensions: 53827800 bytes
# 2024-10-02 17:40:17,024 : INFO : resetting layer weights
# 2024-10-02 17:40:17,056 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-10-02T17:40:17.056791', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'build_vocab'}
# 2024-10-02 17:40:17,059 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 41406 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2024-10-02T17:40:17.059785', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2024-10-02 17:40:18,114 : INFO : EPOCH 0 - PROGRESS: at 5.50% examples, 151877 words/s, in_qsize 6, out_qsize 0
# 2024-10-02 17:40:19,116 : INFO : EPOCH 0 - PROGRESS: at 11.32% examples, 150744 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 17:40:20,120 : INFO : EPOCH 0 - PROGRESS: at 15.85% examples, 148322 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 17:40
words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:09,945 : INFO : EPOCH 4 - PROGRESS: at 77.52% examples, 175136 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:10,974 : INFO : EPOCH 4 - PROGRESS: at 83.01% examples, 173427 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:11,987 : INFO : EPOCH 4 - PROGRESS: at 87.89% examples, 171683 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:13,008 : INFO : EPOCH 4 - PROGRESS: at 93.52% examples, 170733 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:13,983 : INFO : EPOCH 4: training on 3652548 raw words (2597981 effective words) took 15.3s, 169698 effective words/s
# 2024-10-02 20:12:13,984 : INFO : Word2Vec lifecycle event {'msg': 'training on 18262740 raw words (12992833 effective words) took 81.8s, 158917 effective words/s', 'datetime': '2024-10-02T20:12:13.984594', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2024-10-02 20:12:13,985 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=41406, vector_size=100, alpha=0.025>', 'datetime': '2024-10-02T20:12:13.985591', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'created'}
# 2024-10-02 20:12:13,987 : INFO : KeyedVectors lifecycle event {'fname_or_handle': 'C:/Users/Brottrager/Documents/Diss/sec_lit/GER/20240919_wordembeddings\\modelA_iteration=100\\20240919_100_window=10_skipgram_defaultparams_model_vectors.kv', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-10-02T20:12:13.987597', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'saving'}
# 2024-10-02 20:12:14,042 : INFO : saved C:/Users/Brottrager/Documents/Diss/sec_lit/GER/20240919_wordembeddings\modelA_iteration=100\20240919_100_window=10_skipgram_defaultparams_model_vectors.kv

# %%
we_results = path_results + '\\modelB_iteration=' + str(iterations)
if not os.path.exists(we_results):
    os.makedirs(we_results)

# %%
models = []
for i in range(1, iterations+1):
    model = Word2Vec(tokens, min_count=min_count, vector_size=vector_size, window=window, sg=sg, epochs=epochs)
    model.wv.save(path_results + '\\modelB_iteration=' + str(iterations) + '\\' + today + '_' + str(i) + '_window=' + str(window) + '_skipgram_defaultparams_model_vectors.kv')
    models.append(model)
# Out:
# 2024-10-02 20:12:15,168 : INFO : collecting all words and their counts
# 2024-10-02 20:12:15,168 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-10-02 20:12:15,275 : INFO : PROGRESS: at sentence #10000, processed 277781 words, keeping 38708 word types
# 2024-10-02 20:12:15,383 : INFO : PROGRESS: at sentence #20000, processed 573185 words, keeping 63626 word types
# 2024-10-02 20:12:15,508 : INFO : PROGRESS: at sentence #30000, processed 856107 words, keeping 86692 word types
# 2024-10-02 20:12:15,616 : INFO : PROGRESS: at sentence #40000, processed 1117523 words, keeping 104095 word types
# 2024-10-02 20:12:15,721 : INFO : PROGRESS: at sentence #50000, processed 1404857 words, keeping 119278 word types
# 2024-10-02 20:12:15,832 : INFO : PROGRESS: at sentence #60000, processed 1682965 words, keeping 133037 word types
# 2024-10-02 20:12:15,929 : INFO : PROGRESS: at sentence #70000, processed 1911646 words, keeping 148099 word types
# 2024-10-02 20:12:16,034 : INFO : PROGRESS: at sentence #80000, processed 2175572 words, keeping 161655 word types
# 2024-10-02 20:12:16,140 : INFO : PROGRESS: at sentence #90000, processed 2407307 words, keeping 174826 word types
# 2024-10-02 20:12:16,238 : INFO : PROGRESS: at sentence #100000, processed 2660004 words, keeping 190384 word types
# 2024-10-02 20:12:16,344 : INFO : PROGRESS: at sentence #110000, processed 2939003 words, keeping 200941 word types
# 2024-10-02 20:12:16,448 : INFO : PROGRESS: at sentence #120000, processed 3248529 words, keeping 208657 word types
# 2024-10-02 20:12:16,554 : INFO : PROGRESS: at sentence #130000, processed 3528600 words, keeping 222921 word types
# 2024-10-02 20:12:16,608 : INFO : collected 231874 word types from a corpus of 3652548 raw words and 135024 sentences
# 2024-10-02 20:12:16,609 : INFO : Creating a fresh vocabulary
# 2024-10-02 20:12:16,980 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 41406 unique words (17.86% of original 231874, drops 190468)', 'datetime': '2024-10-02T20:12:16.980310', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2024-10-02 20:12:16,981 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 3374733 word corpus (92.39% of original 3652548, drops 277815)', 'datetime': '2024-10-02T20:12:16.981313', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2024-10-02 20:12:17,365 : INFO : deleting the raw counts dictionary of 231874 items
# 2024-10-02 20:12:17,371 : INFO : sample=0.001 downsamples 41 most-common words
# 2024-10-02 20:12:17,373 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2598336.545976942 word corpus (77.0%% of prior 3374733)', 'datetime': '2024-10-02T20:12:17.373739', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'prepare_vocab'}
# 2024-10-02 20:12:17,960 : INFO : estimated required memory for 41406 words and 100 dimensions: 53827800 bytes
# 2024-10-02 20:12:17,961 : INFO : resetting layer weights
# 2024-10-02 20:12:17,989 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-10-02T20:12:17.989275', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'build_vocab'}
# 2024-10-02 20:12:17,991 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 41406 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2024-10-02T20:12:17.991272', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2024-10-02 20:12:19,050 : INFO : EPOCH 0 - PROGRESS: at 5.77% examples, 152261 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:20,062 : INFO : EPOCH 0 - PROGRESS: at 12.30% examples, 160992 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:21,147 : INFO : EPOCH 0 - PROGRESS: at 17.45% examples, 157829 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:22,154 : INFO : EPOCH 0 - PROGRESS: at 24.11% examples, 158377 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:23,182 : INFO : EPOCH 0 - PROGRESS: at 30.30% examples, 158178 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:24,213 : INFO : EPOCH 0 - PROGRESS: at 36.56% examples, 159720 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:25,234 : INFO : EPOCH 0 - PROGRESS: at 42.28% examples, 158860 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:26,300 : INFO : EPOCH 0 - PROGRESS: at 49.86% examples, 158738 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:27,395 : INFO : EPOCH 0 - PROGRESS: at 57.23% examples, 158237 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:28,479 : INFO : EPOCH 0 - PROGRESS: at 64.59% examples, 158207 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:29,569 : INFO : EPOCH 0 - PROGRESS: at 71.21% examples, 157928 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:30,615 : INFO : EPOCH 0 - PROGRESS: at 78.29% examples, 158260 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:31,641 : INFO : EPOCH 0 - PROGRESS: at 83.74% examples, 158079 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12:32,661 : INFO : EPOCH 0 - PROGRESS: at 88.56% examples, 157454 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 20:12
words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:27,566 : INFO : EPOCH 4 - PROGRESS: at 13.74% examples, 185054 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:28,627 : INFO : EPOCH 4 - PROGRESS: at 21.50% examples, 189510 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:29,639 : INFO : EPOCH 4 - PROGRESS: at 29.63% examples, 192494 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:30,656 : INFO : EPOCH 4 - PROGRESS: at 36.81% examples, 193637 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:31,708 : INFO : EPOCH 4 - PROGRESS: at 43.89% examples, 191742 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:32,709 : INFO : EPOCH 4 - PROGRESS: at 52.66% examples, 191351 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:33,774 : INFO : EPOCH 4 - PROGRESS: at 60.28% examples, 190848 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:34,798 : INFO : EPOCH 4 - PROGRESS: at 69.75% examples, 192532 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:35,820 : INFO : EPOCH 4 - PROGRESS: at 78.29% examples, 193270 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:36,822 : INFO : EPOCH 4 - PROGRESS: at 84.93% examples, 193522 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:37,824 : INFO : EPOCH 4 - PROGRESS: at 90.52% examples, 192329 words/s, in_qsize 5, out_qsize 0
# 2024-10-02 22:19:38,867 : INFO : EPOCH 4 - PROGRESS: at 98.87% examples, 192303 words/s, in_qsize 4, out_qsize 0
# 2024-10-02 22:19:38,975 : INFO : EPOCH 4: training on 3652548 raw words (2598008 effective words) took 13.5s, 192773 effective words/s
# 2024-10-02 22:19:38,976 : INFO : Word2Vec lifecycle event {'msg': 'training on 18262740 raw words (12992081 effective words) took 69.7s, 186493 effective words/s', 'datetime': '2024-10-02T22:19:38.976246', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'train'}
# 2024-10-02 22:19:38,977 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=41406, vector_size=100, alpha=0.025>', 'datetime': '2024-10-02T22:19:38.977244', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'created'}
# 2024-10-02 22:19:38,978 : INFO : KeyedVectors lifecycle event {'fname_or_handle': 'C:/Users/Brottrager/Documents/Diss/sec_lit/GER/20240919_wordembeddings\\modelB_iteration=100\\20240919_100_window=10_skipgram_defaultparams_model_vectors.kv', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-10-02T22:19:38.978244', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22631-SP0', 'event': 'saving'}
# 2024-10-02 22:19:39,015 : INFO : saved C:/Users/Brottrager/Documents/Diss/sec_lit/GER/20240919_wordembeddings\modelB_iteration=100\20240919_100_window=10_skipgram_defaultparams_model_vectors.kv

# %% [markdown]
# ### Networks

# %% [markdown]
# #### Network A: All entities

# %%
model_dir = Path(path_results + '\\modelA_iteration=' + str(iterations)).glob('*.kv')
files = list(model_dir)

# %%
models = []

for file in files:
    models.append(gensim.models.KeyedVectors.load(str(file)))
# Out:
# 2025-01-30 17:08:10,185 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_100_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:10,302 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_100_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:10.302978', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:10,304 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_10_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:10,391 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_10_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:10.391044', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:10,394 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_11_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:10,475 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_11_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:10.475557', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:10,477 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_12_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:10,540 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_12_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:10.540637', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:10,542 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_13_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:10,605 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_13_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:10.605165', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:10,607 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_14_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:10,666 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_14_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:10.666165', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:10,667 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_15_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:10,730 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_15_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:10.730805', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:10,732 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_16_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:10,788 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_16_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:10.788385', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:10,789 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_17_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:10,854 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_17_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:10.854095', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:10,856 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_18_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:10,927 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_18_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:10.927629', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:10,929 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_19_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:10,995 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_19_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:10.995649', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:10,996 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_1_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,061 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_1_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11.061192', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:11,063 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_20_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,123 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_20_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11.123718', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:11,124 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_21_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,180 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_21_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11.180758', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:11,182 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_22_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,234 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_22_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11.234857', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:11,235 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_23_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,292 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_23_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11.292225', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:11,293 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_24_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,351 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_24_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11.351721', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:11,353 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_25_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,414 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_25_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11.414917', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:11,415 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_26_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,473 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_26_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11.473026', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:11,474 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_27_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,527 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_27_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11.527987', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:11,528 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_28_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,582 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_28_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11.582954', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:11,584 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_29_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,641 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_29_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11.641331', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:11,642 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_2_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:11,703 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_2_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:11
 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}
# 2025-01-30 17:08:16,589 : INFO : loading KeyedVectors object from C:\Users\Brottrager\Documents\Diss\sec_lit\GER\20240919_wordembeddings\modelA_iteration=100\20240919_9_window=10_skipgram_defaultparams_model_vectors.kv
# 2025-01-30 17:08:16,637 : INFO : KeyedVectors lifecycle event {'fname': 'C:\\Users\\Brottrager\\Documents\\Diss\\sec_lit\\GER\\20240919_wordembeddings\\modelA_iteration=100\\20240919_9_window=10_skipgram_defaultparams_model_vectors.kv', 'datetime': '2025-01-30T17:08:16.637915', 'gensim': '4.3.2', 'python': '3.11.9 | packaged by Anaconda, Inc. | (main, Apr 19 2024, 16:40:41) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'loaded'}

# %%
vectors = {}

for model in models:
    for key in entities:
        if key in model.key_to_index:
            if key not in vectors:
                vectors[key] = [model[key]]
            else:
                vectors[key].append(model[key])

# %%
vectors_mean = {}
idsinEmbedding = []
nodes = {}

for key, values in vectors.items():
    array = np.array(vectors[key], dtype='float32')
    vectors_mean[key] = np.average(array, axis=0)
    idsinEmbedding.append(key)
    if key in entities_per:
        nodes[key] = {'label': 'PERSON'}
    elif key in entities_text:
        nodes[key] = {'label': 'WORK_OF_ART'}

# %%
save_data(base_dir + today + '_idsinEmbedding.json', idsinEmbedding)

# %%
idsinEmbedding = load_data(base_dir + today + '_idsinEmbedding.json')

# %%
len(idsinEmbedding)
# Out:
# 3054

# %%
vectors_ls = []

for key, values in vectors_mean.items():
    vectors_ls.append(vectors_mean[key])

# %%
similarities = cosine_similarity(vectors_ls)

# %%
data = pd.DataFrame(similarities)

# %%
for i in range(0, len(data)):
    for j in range(0,len(data)):
        if i == j:
            data.iloc[i,j] = 0

# %%
data.columns = idsinEmbedding
data.index = idsinEmbedding

# %% [markdown]
# Minimum Spanning Tree

# %%
G = nx.from_pandas_adjacency(data)

# %%
nx.set_node_attributes(G, nodes)

# %%
algorithm = 'kruskal'

# %%
for u, v, data in G.edges(data=True):
    data['weight'] = 1 - data['weight'] # similarity vs minimum weight

mst = nx.minimum_spanning_tree(G, algorithm=algorithm)

for u, v, data in mst.edges(data=True):
    data['weight'] = 1 - data['weight']

# %%
#filename = path_results + '\\' + today + '_min_count' + str(min_count) + '_vector_size' + str(vector_size) + '_window' + str(window) + '_epochs' + str(epochs) + '_' + str(algorithm) + "_word_similarity_edges_highsimilarity.csv"
filename = path_results + '\\' + today + '_window=' + str(window) + "_defaultparams_skipgram_mean5_word_similarity_edges_highsimilarity.csv"

with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Source', 'Target', 'Weight'])
    
    for u, v, data in mst.edges(data=True):
        writer.writerow([u, v, data['weight']])

# %% [markdown]
# #### Network: PER

# %%
vectors_per_ls = []
idsinEmbedding_per = []

for key, values in vectors_mean.items():
    if key in entities_per:
        vectors_per_ls.append(vectors_mean[key])
        idsinEmbedding_per.append(key)

# %%
len(idsinEmbedding_per)
# Out:
# 2110

# %%
similarities_per = cosine_similarity(vectors_per_ls)

# %%
save_data(base_dir + today + '_idsinEmbedding_PER.json', idsinEmbedding_per)

# %%
data_per = pd.DataFrame(similarities_per)

# %%
for i in range(0, len(data_per)):
    for j in range(0,len(data_per)):
        if i == j:
            data_per.iloc[i,j] = 0

# %%
data_per.columns = idsinEmbedding_per
data_per.index = idsinEmbedding_per

# %% [markdown]
# Minimum Spanning Tree

# %%
G_per = nx.from_pandas_adjacency(data_per)

# %%
for u, v, data in G_per.edges(data=True):
    data['weight'] = 1 - data['weight'] # similarity vs minimum weight

mst_per = nx.minimum_spanning_tree(G_per, algorithm=algorithm)

for u, v, data in mst_per.edges(data=True):
    data['weight'] = 1 - data['weight']

# %%
#filename = path_results + '\\' + today + '_min_count' + str(min_count) + '_vector_size' + str(vector_size) + '_window' + str(window) + '_epochs' + str(epochs) + '_' + str(algorithm) + "_word_similarity_edges_highsimilarity_PER.csv"
filename = path_results + '\\' + today + '_window=' + str(window) + "_defaultparams_skipgram_mean5_word_similarity_edges_highsimilarity_PER.csv"

with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Source', 'Target', 'Weight'])
    
    for u, v, data in mst_per.edges(data=True):
        writer.writerow([u, v, data['weight']])

# %% [markdown]
# #### Network: WORK_OF_ART

# %%
vectors_text_ls = []
idsinEmbedding_text = []

for key, values in vectors_mean.items():
    if key in entities_text:
        vectors_text_ls.append(vectors_mean[key])
        idsinEmbedding_text.append(key)

# %%
len(idsinEmbedding_text)
# Out:
# 1264

# %%
save_data(base_dir + today + '_idsinEmbedding_TEXT.json', idsinEmbedding_text)

# %%
similarities_text = cosine_similarity(vectors_text_ls)

# %%
data_texts = pd.DataFrame(similarities_text)

# %%
for i in range(0, len(data_texts)):
    for j in range(0,len(data_texts)):
        if i == j:
            data_texts.iloc[i,j] = 0

# %%
data_texts.columns = idsinEmbedding_text
data_texts.index = idsinEmbedding_text

# %%
data_texts.to_csv(path_results + '\\' + today + '_window=' + str(window) + 'texts_wordembedding_adjacency.csv', encoding='utf8')

# %% [markdown]
# Minimum Spanning Tree

# %%
G_texts = nx.from_pandas_adjacency(data_texts)

# %%
for u, v, data in G_texts.edges(data=True):
    data['weight'] = 1 - data['weight'] # similarity vs minimum weight

mst_texts = nx.minimum_spanning_tree(G_texts, algorithm=algorithm)

for u, v, data in mst_texts.edges(data=True):
    data['weight'] = 1 - data['weight']

# %%
#filename = path_results + '\\' + today + '_min_count' + str(min_count) + '_vector_size' + str(vector_size) + '_window' + str(window) + '_epochs' + str(epochs) + '_' + str(algorithm) + "_word_similarity_edges_highsimilarity_WORK_OF_ART.csv"
filename = path_results + '\\' + today + '_window=' + str(window) + "_defaultparams_skipgram_mean5_word_similarity_edges_highsimilarity_WORK_OF_ART.csv"

with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Source', 'Target', 'Weight'])
    
    for u, v, data in mst_texts.edges(data=True):
        writer.writerow([u, v, data['weight']])

# %%
#filename = path_results + '\\' + today + '_min_count' + str(min_count) + '_vector_size' + str(vector_size) + '_window' + str(window) + '_epochs' + str(epochs) + '_' + str(algorithm) + "_word_similarity_edges_highsimilarity_WORK_OF_ART.csv"
filename = path_results + '\\' + today + '_window=' + str(window) + "_defaultparams_skipgram_mean5_all_WORK_OF_ART.csv"

with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Source', 'Target', 'Weight'])
    
    for u, v, data in G_texts.edges(data=True):
        writer.writerow([u, v, data['weight']])
